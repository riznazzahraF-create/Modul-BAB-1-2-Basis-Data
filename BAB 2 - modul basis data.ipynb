# %% [markdown]
# <a href="https://colab.research.google.com/github/riznazzahraF-create/Modul-BAB-1-2-Basis-Data/blob/main/BAB%202%20-%20modul%20basis%20data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**💻 BAB 2 - Pengantar Basis Data - DDL**
# Pada BAB ini berisi DBMS dan MySQL
#
#
# ---
#
#
# **DBMS (Database Management System)**
#
# Salah satu sistem dalam yang mengakses database menggunakan MySQL
#
#
# ---
#
#
#
# **MySQL (My Structure Query Language)**
#
# merupakan salah satu DBMS dari sekian
# banyak DBMS lain seperti Oracle, MS SQL, PostgresSQL, DLL.
#
#
# ---
#
#
# **Mengakses MySQL**
# - Login MySQL
# - cd C:\xampp\mysql\bin
# - mysql -u root -p
